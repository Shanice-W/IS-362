# %%
from IPython.display import Image
Image(filename=r"\Users\shani\Downloads\Week14.jpg")

# %% [markdown]
# ## Reverse Engineering
# According to Amazon:
#
# "Unlike traditional collaborative filtering, our algorithm’s online computation scales independently of the number of customers and number of items in the product catalog. Our algorithm produces recommendations in realtime, scales to massive data sets, and generates high quality recommendations."(https://datajobs.com/data-science-repo/Recommender-Systems-[Amazon].pdf)
#
# This differs from traditional collaborative methods such as collaborative filtering, clustering, search-based methods.
#
# Customers can also alter their recommendations on the Amazon website. Amazon uses email marketing to send user recommendations where the user can click on the link from their email and when in the recommendations section, can alter and rate their recommendations and recommendations settings.

# %% [markdown]
# ## Recommendation
#
# The clickable link can be replaced with a survey instead. They can also implement a like or dislike option embbed through emails sent with Amazon product recommendations. Similar to the model some online clothing stores are using. Users see the product and like it to see more like it or dislike to see less.
